# %%
import pandas as pd
from sklearn import linear_model
import numpy as np
import matplotlib as plt
data=pd.read_csv('PB2_train.csv',sep=',',header=None)
data
# Out:
#          0      1       2
# 0    146.0   95.0  1636.0
# 1      9.0  151.0   216.0
# 2    150.0   74.0  1384.0
# 3    126.0   43.0  1088.0
# 4     95.0    8.0   832.0
# 5      0.0   65.0   176.0
# 6     49.0   69.0   676.0
# 7     31.0   47.0   684.0
# 8     60.0   56.0   492.0
# 9     95.0  154.0   900.0
# 10     2.0   59.0   116.0
# 11    41.0  130.0   888.0
# 12    61.0   64.0   752.0
# 13   101.0  146.0  1036.0
# 14    71.0   11.0   864.0
# 15   152.0  100.0  1268.0
# 16    99.0   25.0   996.0
# 17   115.0  150.0  1112.0
# 18    65.0  145.0   916.0
# 19    48.0   11.0   428.0
# 20    18.0    0.0   564.0
# 21    18.0   78.0   604.0
# 22    41.0    1.0   560.0
# 23    23.0   11.0   324.0
# 24   115.0  123.0  1552.0
# 25    19.0   24.0   364.0
# 26    59.0  117.0   896.0
# 27    29.0   52.0   472.0
# 28   129.0  101.0  1328.0
# 29    70.0   11.0  1136.0
# ..     ...    ...     ...
# 90     1.0   95.0   444.0
# 91    47.0   31.0   468.0
# 92    42.0   80.0   488.0
# ...

# %%
reg=linear_model.LinearRegression()
reg.fit(data[[0,1]],data[2])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.coef_
# Out:
# array([7.98554746, 0.03573724])

# %%
print('Model Parameters:-')
ϴ1= reg.coef_[0]
ϴ2= reg.coef_[1]
ϴ0=reg.intercept_
print('ϴ0=',ϴ0)
print('ϴ1=',ϴ1)
print('ϴ2=',ϴ2)
# Out:
# Model Parameters:-
# ϴ0= 290.6377035073202
# ϴ1= 7.985547463304989
# ϴ2= 0.035737235735765725

# %%
print('The Given equation y=',ϴ0,'+',ϴ1,'x1''+',ϴ2,'x2')
# Out:
# The Given equation y= 290.6377035073202 + 7.985547463304989 x1+ 0.035737235735765725 x2

# %%
import pandas as pd
test_data=pd.read_csv('PB2_test.csv',sep=',',header=None,usecols=[0,1])
pred_data=reg.predict(test_data)
print('Predicted values on PB2_test.csv\n ',pred_data)
# Out:
# Predicted values on PB2_test.csv
#   [1472.85610043 1329.54509292 1491.54322528  606.00515051  291.45965993
#  1139.75029006  964.42561823  378.62167455  658.72336877 1102.71726884
#   506.74780632  645.53977823  459.51352902 1209.94056715  506.46190843
#   854.95087406  778.89969031  459.97811308  713.9074563  1561.16170659
#  1472.57020255  587.53244908 1226.41198338  834.40541296  646.07583677
#   796.55043532 1075.83017312  291.5311344   718.83919483  687.61174969]

# %%
given_data=pd.read_csv('PB2_test.csv',sep=',',header=None,usecols=[2])
from sklearn.metrics import mean_squared_error
m=mean_squared_error(pred_data,given_data)
print('Mean Squared Error=',m)
# Out:
# Mean Squared Error= 24691.88399295919

# %%
p=reg.predict([[19,76]])
print('y value for x=[19,76] = ',p)
# Out:
# y value for x=[19,76] =  [445.07913523]

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax = plt.axes(projection='3d')
ax.scatter(data[0],data[1],data[2], c='r', marker='o')
plt.xlabel('X')
plt.ylabel('Y')
ax.set_zlabel('Z')
plt.title("Linear regression")
plt.show()
